# %%
import numpy as np
import sys
import cv2

# %%
img = cv2.imread(basedir + '/puppy.bmp', cv2.IMREAD_COLOR)

# %%
print(type(img))
print(img.shape)
print(img.dtype)
# Out:
# <class 'numpy.ndarray'>
# (480, 640, 3)
# uint8

# %%
height, width = img.shape[:2]

# %%
img1 = np.zeros((640, 640, 3), dtype='uint8')
img2 = np.ones((640, 640), dtype='uint8') * 255
img3 = np.full((640, 640, 3), (0, 0, 255), dtype='uint8')

cv2_imshow(img1)
cv2_imshow(img2)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F281957AA50>
# <PIL.Image.Image image mode=L size=640x640 at 0x7F2819531DD0>
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F28194A1610>

# %%
img2 = img
img3 = img.copy() # memcpy
img[200:300, 200:300] = (0, 0, 255)

cv2_imshow(img)
cv2_imshow(img2)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F28194A89D0>
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F28194C0050>
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F2826AD4250>

# %%
src = cv2.imread('/airplane.bmp')
mask = cv2.imread('/mask_plane.bmp', cv2.IMREAD_GRAYSCALE)
dst = cv2.imread('/field.bmp')

dst[mask > 0] = src[mask > 0]

cv2_imshow(src)
cv2_imshow(mask)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F2819585050>
# <PIL.Image.Image image mode=L size=600x400 at 0x7F2826AD4550>
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F28194A8F10>

# %%
cv2_utils.invalidate_state()

img = np.ones((640, 640, 3), dtype='uint8') * 255

cv2.line(img, (50, 50), (300, 50), (0, 0, 255), 5, cv2.LINE_8)
cv2.line(img, (300, 50), (150, 300), (0, 0, 255), 5, cv2.LINE_AA)
cv2.line(img, (400, 50), (400, 300), (255, 0, 0), 2, cv2.LINE_8)

cv2.rectangle(img, (50, 400), (400, 500), (0, 0, 255), 5, cv2.LINE_8)

cv2.imshow('canvas', img)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Allocate JavaScript engine...

# %%
img = np.ones((300, 640, 3), dtype='uint8') * 255

color = (220, 180, 70)

cv2.circle(img, (120, 120), 50, color, 5, cv2.LINE_AA)
cv2.line(img, (200, 50), (200, 170), color, 5, cv2.LINE_8)
cv2.line(img, (80, 170), (80, 230), color, 5, cv2.LINE_8)
cv2.line(img, (80, 230), (200, 230), color, 5, cv2.LINE_8)

cv2.line(img, (300, 50), (260, 150), color, 5, cv2.LINE_AA)
cv2.line(img, (300, 50), (340, 150), color, 5, cv2.LINE_AA)
cv2.line(img, (380, 50), (380, 150), color, 5, cv2.LINE_8)
cv2.line(img, (380, 100), (400, 100), color, 5, cv2.LINE_8)
cv2.rectangle(img, (290, 170, 90, 60), color, 5, cv2.LINE_8)

cv2.imshow('img',img)
cv2.waitKey()
cv2.destoryAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-faf131cb2ea5> in <module>
#      16 cv2.imshow('img',img)
#      17 cv2.waitKey()
# ---> 18 cv2.destoryAllWindows()
#
# AttributeError: module 'cv2' has no attribute 'destoryAllWindows'

# %%
cv2_utils.invalidate_state()

cap = cv2_utils.VideoCapture(0)
if not cap.isOpened():
  print('Failed')
else:
  width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
  height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
  fps = cap.get(cv2.CAP_PROP_FPS)

  print('Width: {}, Height: {}, FPS: {}'.format(width, height, fps))

  while True:
    retval, frame = cap.read()
    if not retval:
      print('Video read failed')
      break
    

    frame = cv2.Canny(frame, 50, 150)
    
    if not cv2_utils.imshow('cap', frame):
      break
cap.release()
# output.release()

cv2_utils.destroyAllWindows()
# Out:
# Allocate JavaScript engine...
# Width: 640, Height: 480, FPS: 5
