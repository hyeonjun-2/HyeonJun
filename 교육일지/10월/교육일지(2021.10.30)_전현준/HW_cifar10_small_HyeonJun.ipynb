# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Fri Oct 29 13:22:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.29.05    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os

# %% [markdown]
# # Load Data

# %%
# 데이터 경로
train_dir = '/content/data/train'
test_dir = '/content/data/test'

# %%
#DataLoader
train_datagen = keras.preprocessing.image.ImageDataGenerator(validation_split=0.2)  # validation set를 만들기 위해 split 계수 넣어줌
test_datagen = keras.preprocessing.image.ImageDataGenerator()

# %%
batch_size = 50
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,  # train_data path
    target_size = (150,150), # train_data sie
    batch_size = batch_size,  # batch_size 
    interpolation = 'bilinear', #보간법 : 이미지의 사이즈를 바꿀때 연결하지 않고 곡선으로 연결함으로써 본래 신호에 대한 변형을 최소화시켜 줌
    color_mode = 'rgb',
    shuffle = 'True',  # 데이터를 섞어서
    class_mode = 'categorical', # Multi Class 분류이므로 categorical (2진분류일경우 binary)
    subset = "training"  # train validaition data split
)

val_generator = train_datagen.flow_from_directory(
    directory = train_dir,
    target_size = (150,150),
    batch_size = batch_size,
    interpolation = 'bilinear',
    color_mode = 'rgb',
    shuffle = 'True',
    class_mode = 'categorical',
    subset = 'validation'
)
test_generator =test_datagen.flow_from_directory(
    directory = test_dir,
    target_size = (150,150),
    batch_size = batch_size,
    interpolation = 'bilinear',
    color_mode = 'rgb',
    shuffle = 'True',
    class_mode = 'categorical'
)
# Out:
# Found 16000 images belonging to 4 classes.
# Found 4000 images belonging to 4 classes.
# Found 4000 images belonging to 4 classes.

# %% [markdown]
# # Augmenation
# 1. Image Flp
# 2. RandomRotate

# %%
augmenation = keras.Sequential(
    [  # 데이터 Augmentation : 데이터를 임의로 늘려준다.
        keras.layers.RandomFlip("horizontal"),   # Augmentation 수평선을 기준으로 뒤집음
        keras.layers.RandomRotation(0.1),   # 각도를 돌림
    ] 
)
model = keras.Sequential([
    keras.Input(shape = (150,150,3)), # input shape지정
    augmenation,
  
    #Convolutional Layers
    keras.layers.Conv2D(32,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),

    keras.layers.Conv2D(64,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
    

    keras.layers.Conv2D(128,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
     keras.layers.Conv2D(256,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
    
    keras.layers.Conv2D(512,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
    
    # Fully Connected Layers to classification
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4,activation = 'softmax')
    ])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_5 (Sequential)    (None, 150, 150, 3)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 150, 150, 32)      896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 150, 150, 32)      128
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 75, 75, 64)        18496
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 37, 37, 128)       73856
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 37, 37, 128)       512
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 18, 18, 256)       295168
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 18, 18, 256)       1024
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 9, 9, 512)         1180160
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 9, 9, 512)         2048
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 5,833,540
# Trainable params: 5,831,556
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
loss = keras.losses.categorical_crossentropy  # set Loss
optim = keras.optimizers.Adam()  # Set optimizer
metric = keras.metrics.categorical_accuracy # set metrics
 
#model compile
model.compile(
    loss = loss,
    optimizer = optim,
    metrics = [metric])

# %%
# 모델 최적화 설정
import os
MODEL_DIR = '/content/model_data2'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath= MODEL_DIR + '/{epoch:02d}-{val_loss:.4f}.hdf5'
callback_list=[tf.keras.callbacks.ModelCheckpoint(filepath = modelpath, monitor = 'val_loss',verbose = 1,save_best_only= True),  #모델의 체크포인트
               tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)]  # 오버피팅 방지를 위해 Early stop / 10 에폭동안 loss가 최소로스보다 크면 종료

# %%
train_aeroplane_dir = os.path.join(train_dir,'aeroplane')
train_bird_dir = os.path.join(train_dir,'bird')
train_car_dir = os.path.join(train_dir,'car')
train_cat_dir = os.path.join(train_dir,'cat')

number =  len(os.listdir(train_aeroplane_dir)) + len(os.listdir(train_bird_dir)) + len(os.listdir(train_car_dir)) + len(os.listdir(train_cat_dir))
number = number - number*0.2
history = model.fit(
    train_generator, # train_data laoder
    steps_per_epoch = (number / batch_size), #epochs별 학습회수 전체 데이터 세트 / 배치사이즈 
    epochs = 1000, 
    validation_data = val_generator, # 오버피팅 확인을 위한 검증 세트
    callbacks = callback_list, # callback Function
    validation_freq = 1, # 1에폭마다 검증
)
# Out:
# Epoch 1/1000
# 320/320 [==============================] - 76s 136ms/step - loss: 1.6110 - categorical_accuracy: 0.5336 - val_loss: 0.9290 - val_categorical_accuracy: 0.6225
#
# Epoch 00001: val_loss improved from inf to 0.92896, saving model to /content/model_data2/01-0.9290.hdf5
# Epoch 2/1000
# 320/320 [==============================] - 44s 137ms/step - loss: 0.8951 - categorical_accuracy: 0.6395 - val_loss: 0.7697 - val_categorical_accuracy: 0.6902
#
# Epoch 00002: val_loss improved from 0.92896 to 0.76971, saving model to /content/model_data2/02-0.7697.hdf5
# Epoch 3/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.7910 - categorical_accuracy: 0.6991 - val_loss: 0.8097 - val_categorical_accuracy: 0.6795
#
# Epoch 00003: val_loss did not improve from 0.76971
# Epoch 4/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.7134 - categorical_accuracy: 0.7239 - val_loss: 0.6886 - val_categorical_accuracy: 0.7160
#
# Epoch 00004: val_loss improved from 0.76971 to 0.68863, saving model to /content/model_data2/04-0.6886.hdf5
# Epoch 5/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.6597 - categorical_accuracy: 0.7491 - val_loss: 0.6534 - val_categorical_accuracy: 0.7337
#
# Epoch 00005: val_loss improved from 0.68863 to 0.65340, saving model to /content/model_data2/05-0.6534.hdf5
# Epoch 6/1000
# 320/320 [==============================] - 43s 136ms/step - loss: 0.6222 - categorical_accuracy: 0.7653 - val_loss: 0.6062 - val_categorical_accuracy: 0.7523
#
# Epoch 00006: val_loss improved from 0.65340 to 0.60622, saving model to /content/model_data2/06-0.6062.hdf5
# Epoch 7/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.5605 - categorical_accuracy: 0.7913 - val_loss: 0.5867 - val_categorical_accuracy: 0.7853
#
# Epoch 00007: val_loss improved from 0.60622 to 0.58667, saving model to /content/model_data2/07-0.5867.hdf5
# Epoch 8/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.5129 - categorical_accuracy: 0.8086 - val_loss: 0.6780 - val_categorical_accuracy: 0.7157
#
# Epoch 00008: val_loss did not improve from 0.58667
# Epoch 9/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.4881 - categorical_accuracy: 0.8173 - val_loss: 0.5293 - val_categorical_accuracy: 0.7872
#
# Epoch 00009: val_loss improved from 0.58667 to 0.52927, saving model to /content/model_data2/09-0.5293.hdf5
# Epoch 10/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.4640 - categorical_accuracy: 0.8278 - val_loss: 0.4679 - val_categorical_accuracy: 0.8110
#
# Epoch 00010: val_loss improved from 0.52927 to 0.46785, saving model to /content/model_data2/10-0.4679.hdf5
# Epoch 11/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.4403 - categorical_accuracy: 0.8354 - val_loss: 0.5306 - val_categorical_accuracy: 0.7970
#
# Epoch 00011: val_loss did not improve from 0.46785
# Epoch 12/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.4137 - categorical_accuracy: 0.8464 - val_loss: 0.4448 - val_categorical_accuracy: 0.8150
#
# Epoch 00012: val_loss improved from 0.46785 to 0.44484, saving model to /content/model_data2/12-0.4448.hdf5
# Epoch 13/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.4025 - categorical_accuracy: 0.8543 - val_loss: 0.4619 - val_categorical_accuracy: 0.8123
#
# Epoch 00013: val_loss did not improve from 0.44484
# Epoch 14/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3751 - categorical_accuracy: 0.8625 - val_loss: 0.3911 - val_categorical_accuracy: 0.8640
#
# Epoch 00014: val_loss improved from 0.44484 to 0.39111, saving model to /content/model_data2/14-0.3911.hdf5
# Epoch 15/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3665 - categorical_accuracy: 0.8648 - val_loss: 0.4056 - val_categorical_accuracy: 0.8415
#
# Epoch 00015: val_loss did not improve from 0.39111
# Epoch 16/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3443 - categorical_accuracy: 0.8765 - val_loss: 0.4835 - val_categorical_accuracy: 0.8180
#
# Epoch 00016: val_loss did not improve from 0.39111
# Epoch 17/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3437 - categorical_accuracy: 0.8741 - val_loss: 0.4357 - val_categorical_accuracy: 0.8290
#
# Epoch 00017: val_loss did not improve from 0.39111
# Epoch 18/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3317 - categorical_accuracy: 0.8827 - val_loss: 0.4940 - val_categorical_accuracy: 0.8278
#
# Epoch 00018: val_loss did not improve from 0.39111
# Epoch 19/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3229 - categorical_accuracy: 0.8816 - val_loss: 0.4389 - val_categorical_accuracy: 0.8332
#
# Epoch 00019: val_loss did not improve from 0.39111
# Epoch 20/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.3011 - categorical_accuracy: 0.8929 - val_loss: 0.3789 - val_categorical_accuracy: 0.8612
#
# Epoch 00020: val_loss improved from 0.39111 to 0.37886, saving model to /content/model_data2/20-0.3789.hdf5
# Epoch 21/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2979 - categorical_accuracy: 0.8941 - val_loss: 0.4070 - val_categorical_accuracy: 0.8580
#
# Epoch 00021: val_loss did not improve from 0.37886
# Epoch 22/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2933 - categorical_accuracy: 0.8963 - val_loss: 0.3689 - val_categorical_accuracy: 0.8648
#
# Epoch 00022: val_loss improved from 0.37886 to 0.36887, saving model to /content/model_data2/22-0.3689.hdf5
# Epoch 23/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2811 - categorical_accuracy: 0.8996 - val_loss: 0.5334 - val_categorical_accuracy: 0.8257
#
# Epoch 00023: val_loss did not improve from 0.36887
# Epoch 24/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2711 - categorical_accuracy: 0.9051 - val_loss: 0.4318 - val_categorical_accuracy: 0.8347
#
# Epoch 00024: val_loss did not improve from 0.36887
# Epoch 25/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2646 - categorical_accuracy: 0.9071 - val_loss: 0.3373 - val_categorical_accuracy: 0.8717
#
# Epoch 00025: val_loss improved from 0.36887 to 0.33727, saving model to /content/model_data2/25-0.3373.hdf5
# Epoch 26/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2533 - categorical_accuracy: 0.9086 - val_loss: 0.3655 - val_categorical_accuracy: 0.8652
#
# Epoch 00026: val_loss did not improve from 0.33727
# Epoch 27/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2518 - categorical_accuracy: 0.9111 - val_loss: 0.3948 - val_categorical_accuracy: 0.8593
#
# Epoch 00027: val_loss did not improve from 0.33727
# Epoch 28/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2450 - categorical_accuracy: 0.9124 - val_loss: 0.3602 - val_categorical_accuracy: 0.8720
#
# Epoch 00028: val_loss did not improve from 0.33727
# Epoch 29/1000
# 320/320 [==============================] - 43s 136ms/step - loss: 0.2409 - categorical_accuracy: 0.9164 - val_loss: 0.4521 - val_categorical_accuracy: 0.8260
#
# Epoch 00029: val_loss did not improve from 0.33727
# Epoch 30/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2350 - categorical_accuracy: 0.9179 - val_loss: 0.4004 - val_categorical_accuracy: 0.8658
#
# Epoch 00030: val_loss did not improve from 0.33727
# Epoch 31/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2288 - categorical_accuracy: 0.9186 - val_loss: 0.4045 - val_categorical_accuracy: 0.8720
#
# Epoch 00031: val_loss did not improve from 0.33727
# Epoch 32/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2217 - categorical_accuracy: 0.9217 - val_loss: 0.3792 - val_categorical_accuracy: 0.8720
#
# Epoch 00032: val_loss did not improve from 0.33727
# Epoch 33/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2139 - categorical_accuracy: 0.9256 - val_loss: 0.4173 - val_categorical_accuracy: 0.8605
#
# Epoch 00033: val_loss did not improve from 0.33727
# Epoch 34/1000
# 320/320 [==============================] - 43s 135ms/step - loss: 0.2166 - categorical_accuracy: 0.9232 - val_loss: 0.4176 - val_categorical_accuracy: 0.8367
#
# Epoch 00034: val_loss did not improve from 0.33727
# Epoch 35/1000
# 320/320 [==============================] - 43s 136ms/step - loss: 0.2010 - categorical_accuracy: 0.9282 - val_loss: 0.4575 - val_categorical_accuracy: 0.8520
#
# Epoch 00035: val_loss did not improve from 0.33727

# %% [markdown]
# # Without Augmentaiton

# %%
model2 = keras.Sequential([
    
    keras.Input(shape = (150,150,3)), # input shape지정

    #Convolutional Layers
    keras.layers.Conv2D(32,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),

    keras.layers.Conv2D(64,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
    

    keras.layers.Conv2D(128,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
     keras.layers.Conv2D(256,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
    
    keras.layers.Conv2D(512,3, padding = 'same',activation = 'relu',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(),
    
    # Fully Connected Layers to classification
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4,activation = 'softmax')
    ])

model2.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 150, 150, 32)      896
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 150, 150, 32)      128
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 75, 75, 64)        18496
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 37, 37, 128)       73856
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 37, 37, 128)       512
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 18, 18, 256)       295168
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 18, 18, 256)       1024
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 9, 9, 512)         1180160
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 9, 9, 512)         2048
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 5,833,540
# Trainable params: 5,831,556
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
#model compile
model2.compile(
    loss = loss,
    optimizer = optim,
    metrics = [metric])

# %%
# 모델 최적화 설정
import os
MODEL_DIR = '/content/model_data3'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath= MODEL_DIR + '/{epoch:02d}-{val_loss:.4f}.hdf5'
callback_list=[tf.keras.callbacks.ModelCheckpoint(filepath = modelpath, monitor = 'val_loss',verbose = 1,save_best_only= True),  #모델의 체크포인트
               tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)]  # 오버피팅 방지를 위해 Early stop / 10 에폭동안 loss가 최소로스보다 크면 종료

# %%
train_aeroplane_dir = os.path.join(train_dir,'aeroplane')
train_bird_dir = os.path.join(train_dir,'bird')
train_car_dir = os.path.join(train_dir,'car')
train_cat_dir = os.path.join(train_dir,'cat')

number =  len(os.listdir(train_aeroplane_dir)) + len(os.listdir(train_bird_dir)) + len(os.listdir(train_car_dir)) + len(os.listdir(train_cat_dir))
number = number - number*0.2
history2 = model2.fit(
    train_generator, # train_data laoder
    steps_per_epoch = (number / batch_size), #epochs별 학습회수 전체 데이터 세트 / 배치사이즈 
    epochs = 1000, 
    validation_data = val_generator, # 오버피팅 확인을 위한 검증 세트
    callbacks = callback_list, # callback Function
    validation_freq = 1, # 1에폭마다 검증
)
# Out:
# Epoch 1/1000
# 320/320 [==============================] - 43s 132ms/step - loss: 2.0644 - categorical_accuracy: 0.3275 - val_loss: 1.2490 - val_categorical_accuracy: 0.3965
#
# Epoch 00001: val_loss improved from inf to 1.24903, saving model to /content/model_data3/01-1.2490.hdf5
# Epoch 2/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 1.2073 - categorical_accuracy: 0.4323 - val_loss: 1.1229 - val_categorical_accuracy: 0.5055
#
# Epoch 00002: val_loss improved from 1.24903 to 1.12294, saving model to /content/model_data3/02-1.1229.hdf5
# Epoch 3/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 1.0253 - categorical_accuracy: 0.5558 - val_loss: 0.9699 - val_categorical_accuracy: 0.5982
#
# Epoch 00003: val_loss improved from 1.12294 to 0.96987, saving model to /content/model_data3/03-0.9699.hdf5
# Epoch 4/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.9072 - categorical_accuracy: 0.6281 - val_loss: 0.8596 - val_categorical_accuracy: 0.6670
#
# Epoch 00004: val_loss improved from 0.96987 to 0.85963, saving model to /content/model_data3/04-0.8596.hdf5
# Epoch 5/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.8373 - categorical_accuracy: 0.6754 - val_loss: 0.7627 - val_categorical_accuracy: 0.6960
#
# Epoch 00005: val_loss improved from 0.85963 to 0.76271, saving model to /content/model_data3/05-0.7627.hdf5
# Epoch 6/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.7593 - categorical_accuracy: 0.7084 - val_loss: 0.7948 - val_categorical_accuracy: 0.6820
#
# Epoch 00006: val_loss did not improve from 0.76271
# Epoch 7/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.7080 - categorical_accuracy: 0.7313 - val_loss: 0.7188 - val_categorical_accuracy: 0.7130
#
# Epoch 00007: val_loss improved from 0.76271 to 0.71877, saving model to /content/model_data3/07-0.7188.hdf5
# Epoch 8/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.6406 - categorical_accuracy: 0.7598 - val_loss: 0.6715 - val_categorical_accuracy: 0.7520
#
# Epoch 00008: val_loss improved from 0.71877 to 0.67148, saving model to /content/model_data3/08-0.6715.hdf5
# Epoch 9/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.5804 - categorical_accuracy: 0.7851 - val_loss: 0.7399 - val_categorical_accuracy: 0.7222
#
# Epoch 00009: val_loss did not improve from 0.67148
# Epoch 10/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.5232 - categorical_accuracy: 0.8039 - val_loss: 0.6126 - val_categorical_accuracy: 0.7550
#
# Epoch 00010: val_loss improved from 0.67148 to 0.61256, saving model to /content/model_data3/10-0.6126.hdf5
# Epoch 11/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.4783 - categorical_accuracy: 0.8257 - val_loss: 0.5691 - val_categorical_accuracy: 0.7905
#
# Epoch 00011: val_loss improved from 0.61256 to 0.56910, saving model to /content/model_data3/11-0.5691.hdf5
# Epoch 12/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.4279 - categorical_accuracy: 0.8507 - val_loss: 0.5822 - val_categorical_accuracy: 0.7790
#
# Epoch 00012: val_loss did not improve from 0.56910
# Epoch 13/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.3809 - categorical_accuracy: 0.8631 - val_loss: 0.5217 - val_categorical_accuracy: 0.8077
#
# Epoch 00013: val_loss improved from 0.56910 to 0.52173, saving model to /content/model_data3/13-0.5217.hdf5
# Epoch 14/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.3258 - categorical_accuracy: 0.8841 - val_loss: 0.5435 - val_categorical_accuracy: 0.8098
#
# Epoch 00014: val_loss did not improve from 0.52173
# Epoch 15/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.3139 - categorical_accuracy: 0.8949 - val_loss: 0.5928 - val_categorical_accuracy: 0.8117
#
# Epoch 00015: val_loss did not improve from 0.52173
# Epoch 16/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.2816 - categorical_accuracy: 0.9035 - val_loss: 0.5921 - val_categorical_accuracy: 0.7972
#
# Epoch 00016: val_loss did not improve from 0.52173
# Epoch 17/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.2634 - categorical_accuracy: 0.9126 - val_loss: 0.5861 - val_categorical_accuracy: 0.8240
#
# Epoch 00017: val_loss did not improve from 0.52173
# Epoch 18/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.2175 - categorical_accuracy: 0.9251 - val_loss: 0.6103 - val_categorical_accuracy: 0.8320
#
# Epoch 00018: val_loss did not improve from 0.52173
# Epoch 19/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.1827 - categorical_accuracy: 0.9379 - val_loss: 0.7583 - val_categorical_accuracy: 0.8158
#
# Epoch 00019: val_loss did not improve from 0.52173
# Epoch 20/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.1845 - categorical_accuracy: 0.9404 - val_loss: 0.6629 - val_categorical_accuracy: 0.8232
#
# Epoch 00020: val_loss did not improve from 0.52173
# Epoch 21/1000
# 320/320 [==============================] - 42s 131ms/step - loss: 0.1503 - categorical_accuracy: 0.9491 - val_loss: 0.6848 - val_categorical_accuracy: 0.8067
#
# Epoch 00021: val_loss did not improve from 0.52173
# Epoch 22/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.1401 - categorical_accuracy: 0.9553 - val_loss: 0.6835 - val_categorical_accuracy: 0.8372
#
# Epoch 00022: val_loss did not improve from 0.52173
# Epoch 23/1000
# 320/320 [==============================] - 42s 130ms/step - loss: 0.1384 - categorical_accuracy: 0.9571 - val_loss: 0.8446 - val_categorical_accuracy: 0.8200
#
# Epoch 00023: val_loss did not improve from 0.52173

# %% [markdown]
# # Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize = (20,10))
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
# with out augmentaion
y_vloss2 = history2.history['val_loss']
y_loss2 = history2.history['loss']
acc2 = history2.history['categorical_accuracy']
val_acc2 = history2.history['val_categorical_accuracy']

# 그래프로 표현
plt.subplot(2,2,1)
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c="red", label='validation_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Augmentation Loss')
plt.subplot(2,2,2)
x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker='.', c="red", label='Testset_acc')
plt.plot(x_len, val_acc, marker='.', c="blue", label='Vaidation_acc')
plt.legend(loc='lower right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('ACC')
plt.title('Augmentation ACC')

plt.subplot(2,2,3)
x_len = np.arange(len(y_loss2))
plt.plot(x_len, y_vloss2, marker='.', c="red", label='Validation_loss')
plt.plot(x_len, y_loss2, marker='.', c="blue", label='Training_loss')
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title("Without Augmentation")

plt.subplot(2,2,4)
x_len = np.arange(len(acc2))
plt.plot(x_len, acc2, marker='.', c="red", label='Testset_acc')
plt.plot(x_len, val_acc2, marker='.', c="blue", label='Vaidation_acc')
plt.legend(loc='lower right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('ACC')
plt.title('Without Augmentation ACC')

plt.show()

# %% [markdown]
# # Evaluate

# %%
model.evaluate(test_generator) # augmenation
# Out:
# 80/80 [==============================] - 5s 60ms/step - loss: 0.3225 - categorical_accuracy: 0.8865
# [0.32248446345329285, 0.8865000009536743]

# %%
model2.evaluate(test_generator) # Not augmentation
# Out:
# 80/80 [==============================] - 5s 60ms/step - loss: 0.6609 - categorical_accuracy: 0.8510
# [0.6609358787536621, 0.8510000109672546]

# %% [markdown]
# ## test data evaluate결과 augmentation을 적용한 데이터로 학습한 모델의 결과가 3% 더 높음

# %% [markdown]
# #Predict

# %%
#plot
class_names= ['airplane', 'automobile', 'bird', 'cat']
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img/255, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
  

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                )

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(4), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
image,label = next(test_generator)

# %%
image.shape
# Out:
# (50, 150, 150, 3)

# %%
predictions  = model.predict(image[:15])

num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], label[:15].argmax(axis=1), image[:15])
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], label[:15].argmax(axis=1))
plt.tight_layout()
plt.suptitle('Use Augmentation Model',y=1.05)
plt.show()

# %%
predictions  = model2.predict(image[:15])

num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], label[:15].argmax(axis=1), image[:15])
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], label[:15].argmax(axis=1))
plt.tight_layout()
plt.suptitle('Without Augmentation Model',y=1.05)
plt.show()

# %% [markdown]
# # 느낀점
# ---
# 1. 딥러닝 네트워크 구조를 어떻게 하는가에 따라 모델의 성능이 매우 달라진것을 봤다.네트워크의 중요성을 깨달았다.
# 1. 데이터의 양이 매우 중요하다. Augmentation을 많이 하지 않았음에도 불구하고 모델의 성능이 더 잘나왔다.
# 1. 하드웨어가 받쳐줘야 한다. 네트워크를 레이어를 조금 더 쌓아서 모델의 성능을 올려보려 했지만 Out of Memory가 났다. 네트워크를 설계할 때 데이터의 용량과 사용하고자하는 컴퓨터의 메모리도 고려해서 설계해야겠다.
